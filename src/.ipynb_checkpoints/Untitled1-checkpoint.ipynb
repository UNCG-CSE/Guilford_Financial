dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Guilford County Public Schools - Operating"]
# Out:
# Year
# 2013    175630398
# 2014    177130398
# 2015    179360398
# 2016    183360398
# 2017    188360398
# 2018    195860398
# Name: Amount, dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Debt Service"]
# Out:
# Year
# 2015    90933012
# 2014    91024691
# 2013    92010729
# 2016    92163871
# 2017    93206212
# 2018    99725281
# Name: Amount, dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Social Services"]
# Out:
# Year
# 2018    64922230
# 2013    67834829
# 2014    69153442
# 2015    70023056
# 2016    73270883
# 2017    78580101
# Name: Amount, dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Law Enforcement"]
# Out:
# Year
# 2014    62514387
# 2013    63067577
# 2015    63925042
# 2016    64878973
# 2017    65125442
# 2018    66601596
# Name: Amount, dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Health Care & Wellness"]
# Out:
# Year
# 2013    37464478
# 2015    38263174
# 2016    39114318
# 2017    40008808
# 2014    40756263
# 2018    42493002
# Name: Amount, dtype: int64

# %%
Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Emergency Services"]
# Out:
# Year
# 2014    24520231
# 2013    25143865
# 2015    25467466
# 2016    27096095
# 2017    28529509
# 2018    29847342
# Name: Amount, dtype: int64

# %%
a=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Emergency Services"]
b=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Health Care & Wellness"]
c=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Law Enforcement"]
d=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Social Services"]
e=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Debt Service"]
f=Expense_Budget.groupby(by=["Dept Name","Year"]).Amount.sum().sort_values(ascending =True).loc["Guilford County Public Schools - Operating"]

a=pd.DataFrame({"Year":a.index,"Emergency Services":a.values})
b=pd.DataFrame({"Year":b.index,"Health Care & Wellness":b.values})
c=pd.DataFrame({"Year":c.index,"Law Enforcement":c.values})
d=pd.DataFrame({"Year":d.index,"Social Services":d.values})
e=pd.DataFrame({"Year":e.index,"Debt Service":e.values})
f=pd.DataFrame({"Year":f.index,"Guilford County Public Schools - Operating":f.values})

# %%
g=a.merge([b,c,d,e,f],how="inner",on="Year")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-3e91eeb943f5> in <module>()
# ----> 1 g=a.merge([b,c,d,e,f],how="inner",on="Year")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    5368                      right_on=right_on, left_index=left_index,
#    5369                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 5370                      copy=copy, indicator=indicator, validate=validate)
#    5371
#    5372     def round(self, decimals=0, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     539         if not isinstance(right, DataFrame):
#     540             raise ValueError('can not merge DataFrame with instance of '
# --> 541                              'type {right}'.format(right=type(right)))
#     542
#     543         if not is_bool(left_index):
#
# ValueError: can not merge DataFrame with instance of type <class 'list'>

# %%
from functools import reduce
dfs=[a,b,c,d,e,f]
df_final = reduce(lambda left,right: pd.merge(left,right,on='Year'), dfs)

# %%
df_final
# Out:
#    Emergency Services  Year  Health Care & Wellness  Law Enforcement  \
# 0            24520231  2014                40756263         62514387
# 1            25143865  2013                37464478         63067577
# 2            25467466  2015                38263174         63925042
# 3            27096095  2016                39114318         64878973
# 4            28529509  2017                40008808         65125442
# 5            29847342  2018                42493002         66601596
#
#    Social Services  Debt Service  Guilford County Public Schools - Operating
# 0         69153442      91024691                                   177130398
# 1         67834829      92010729                                   175630398
# 2         70023056      90933012                                   179360398
# 3         73270883      92163871                                   183360398
# 4         78580101      93206212                                   188360398
# 5         64922230      99725281                                   195860398

# %%
df_final.set_index("Year",inplace=True)

# %%
df_final
# Out:
#       Emergency Services  Health Care & Wellness  Law Enforcement  \
# Year
# 2014            24520231                40756263         62514387
# 2013            25143865                37464478         63067577
# 2015            25467466                38263174         63925042
# 2016            27096095                39114318         64878973
# 2017            28529509                40008808         65125442
# 2018            29847342                42493002         66601596
#
#       Social Services  Debt Service  \
# Year
# 2014         69153442      91024691
# 2013         67834829      92010729
# 2015         70023056      90933012
# 2016         73270883      92163871
# 2017         78580101      93206212
# 2018         64922230      99725281
#
#       Guilford County Public Schools - Operating
# Year
# 2014                                   177130398
# 2013                                   175630398
# 2015                                   179360398
# 2016                                   183360398
# 2017                                   188360398
# 2018                                   195860398

# %%
_ = df_final.hist(sharex=True, sharey=True, grid=False, ec='black')
plt.tight_layout()

# %%
_ = df_final.hist( grid=False,ec='black')
plt.show()

# %%
df_final_mean=df_final.mean()
df_final_mean
# Out:
# Emergency Services                            2.676742e+07
# Health Care & Wellness                        3.968334e+07
# Law Enforcement                               6.435217e+07
# Social Services                               7.063076e+07
# Debt Service                                  9.317730e+07
# Guilford County Public Schools - Operating    1.832837e+08
# dtype: float64

# %%
df_final_var=df_final.var()
df_final_var
# Out:
# Emergency Services                            4.414915e+12
# Health Care & Wellness                        3.283060e+12
# Law Enforcement                               2.229090e+12
# Social Services                               2.262372e+13
# Debt Service                                  1.098707e+13
# Guilford County Public Schools - Operating    5.915611e+13
# dtype: float64

# %%
alpha_mom = df_final_mean ** 2 / df_final_var
beta_mom = df_final_var / df_final_mean

# %%
from scipy.stats.distributions import gamma

df_final["Debt Service"].hist(density=True, bins=30, ec='black')
label = 'alpha = {0:.2f}\nbeta = {1:.2f}'.format(alpha_mom[0], beta_mom[0])
plt.annotate(label, xy=(100, .1))
plt.plot(np.linspace(0, 10), gamma.pdf(np.linspace(0, 10), alpha_mom[0], beta_mom[0]))

# %%
axs = df_final.hist(density=True, figsize=(12, 8), sharex=True, sharey=True, bins=100, grid=False, ec='blue')

for ax in axs.ravel():
    
    # Get month
    m = ax.get_title()
    
    # Plot fitted distribution
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, gamma.pdf(x, alpha_mom[m], beta_mom[m]))
    
    # Annotate with parameter estimates
    label = 'alpha = {0:.2f}\nbeta = {1:.2f}'.format(alpha_mom[m], beta_mom[m])
    ax.annotate(label, xy=(100, 0.2))
    
plt.tight_layout()

# %%
a=(Expense_Budget.groupby(by=["Year","Dept Name"]).Amount.sum().sort_values(ascending =False).loc[2014][0:10])

# %%
a.values
# Out:
# array([177130398,  91024691,  69153442,  62514387,  40756263,  31099347,
#         24520231,  12397690,   9900000,   9443738], dtype=int64)

# %%
b=pd.DataFrame({"Dept":a.index,"Amount":a.values})

# %%
b
# Out:
#       Amount                                              Dept
# 0  177130398        Guilford County Public Schools - Operating
# 1   91024691                                      Debt Service
# 2   69153442                                   Social Services
# 3   62514387                                   Law Enforcement
# 4   40756263                            Health Care & Wellness
# 5   31099347                                     Public Health
# 6   24520231                                Emergency Services
# 7   12397690  Guilford Technical Community College - Operating
# 8    9900000                                     Mental Health
# 9    9443738                                   Human Resources

# %%
a.columns
# Out:
# Index(['Amount'], dtype='object')

# %%
z=df_final.median()

# %%
df_final
# Out:
#       Emergency Services  Health Care & Wellness  Law Enforcement  \
# Year
# 2014            24520231                40756263         62514387
# 2013            25143865                37464478         63067577
# 2015            25467466                38263174         63925042
# 2016            27096095                39114318         64878973
# 2017            28529509                40008808         65125442
# 2018            29847342                42493002         66601596
#
#       Social Services  Debt Service  \
# Year
# 2014         69153442      91024691
# 2013         67834829      92010729
# 2015         70023056      90933012
# 2016         73270883      92163871
# 2017         78580101      93206212
# 2018         64922230      99725281
#
#       Guilford County Public Schools - Operating
# Year
# 2014                                   177130398
# 2013                                   175630398
# 2015                                   179360398
# 2016                                   183360398
# 2017                                   188360398
# 2018                                   195860398

# %%
Expense_Budget
# Out:
#        Service #                                  Service Name  Fund #  \
# 7         125120                    IA Energy fellowship Grant     100
# 8         125120                    IA Energy fellowship Grant     100
# 9         125120                    IA Energy fellowship Grant     100
# 10        150210                              ROD - High Point     100
# 11        125120                    IA Energy fellowship Grant     100
# 12        210385                    High Risk Maternity Clinic     100
# 13        125120                    IA Energy fellowship Grant     100
# 14        210170                Community Alternatives Program     100
# 15        210625                 Medication Assistance Progm 2     100
# 16        310120                LP-Civil Proc-Warrant Repostry     100
# 17        230055                 Child Subsidized Day Care Adm     100
# 18        250110                     Human Svcs Transportation     100
# 19        250115                       Medicaid Transportation     100
# 20        150210                              ROD - High Point     100
# 21        210532                   Lead-HUD Gsbo Healthy Homes     100
# 22        210190                 Community Servcs Coordination     100
# 23        210235                    Maternal Care Coordination     100
# 24        210105                                  AIDS-Federal     100
# 25        210250                    Statewide Health Promotion     100
# 26        175310                         Distribution Services     100
# 27        210335                 Communicable Disease TB State     100
# 28        210220                         Healthy Carolinians-B     100
# 29        210350                       Employee Health Service     100
# 30        220030                                          CFAC     100
# 31        410110                          Scrap Tires Disposal     100
# 32        410120                          White Goods Disposal     100
# 33        210235                    Maternal Care Coordination     100
# 34        210605                               Dental-Children     100
# 35        210250                    Statewide Health Promotion     100
# 36        210455                                     Vasectomy     100
# ...          ...                                           ...     ...
# 21888     210240                                School Nursing     100
# 21889     140210                            IS Client Services     100
# 21890     235110                  Special Assistance to Adults     100
# 21891     197141                             Dental - Retirees     200
# 21892     220705                 GC Substance Abuse Allocation     100
# 21893     310701  Detention Services - Greensboro Jail Central     100
a["Service #"].value_counts()
# Out:
# 320410    236
# 320002    177
# 320510    169
# 320110    149
# 320310    146
# 320520    136
# 320210     41
# 320610     17
# 320220      6
# 320211      6
# Name: Service #, dtype: int64

# %%
import seaborn as sns
sns.set(color_codes=True)
# import seaborn
import seaborn as sns
# settings for seaborn plotting style
sns.set(color_codes=True)
# settings for seaborn plot sizes
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.distplot(a.Amount,
                  kde=True,
                  hist=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Amount', ylabel='Probability')
# Out:
# [Text(0,0.5,'Probability'), Text(0.5,0,'Amount')]

# %%
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.distplot(a.Amount,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Amount', ylabel='Frequency')
# Out:
# [Text(0,0.5,'Frequency'), Text(0.5,0,'Amount')]

# %%
b=Expense_Budget[Expense_Budget["Dept Name"]=="Health Care & Wellness"]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(a.Amount, hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 3},
             hist_kws={"linewidth": 15,'alpha':1},
             label = 'Emergency Services')
sns.distplot(b.Amount, hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 3},
             hist_kws={"linewidth": 15,'alpha':1},
             label="Health Care & Wellness"
             )
# plt.set_label(xlabel='Amount', ylabel='Probability')
plt.xlabel("Amount")
plt.ylabel("Probability")
# plt.xlim(1.0)
plt.show()

# %%
high=["Guilford County Public Schools - Operating","Debt Service","Social Services","Law Enforcement","Health Care & Wellness"]
low=["Veteran Services","Soil & Water Conservation","Purchasing","Clerk to the Board","Family Justice Center"]

# %%
Expense_Budget["Dept Name"].item in high
# Out:
# False

# %%
Expense_Budget[Expense_Budget["Dept Name"] in high].groupby(by=["Year","Dept Name"])["Amount"].sum().sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-14eb06705bff> in <module>()
# ----> 1 Expense_Budget[(Expense_Budget["Dept Name"] in high).any].groupby(by=["Year","Dept Name"])["Amount"].sum().sort_values(ascending = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
Expense_Budget.groupby(by=["Year","Dept Name"])["Amount"].sum().sort_values(ascending = False)
# Out:
# Year  Dept Name
# 2018  Guilford County Public Schools - Operating    195860398
# 2017  Guilford County Public Schools - Operating    188360398
# 2016  Guilford County Public Schools - Operating    183360398
# 2015  Guilford County Public Schools - Operating    179360398
# 2014  Guilford County Public Schools - Operating    177130398
# 2013  Guilford County Public Schools - Operating    175630398
# 2018  Debt Service                                   99725281
# 2017  Debt Service                                   93206212
# 2016  Debt Service                                   92163871
# 2013  Debt Service                                   92010729
# 2014  Debt Service                                   91024691
# 2015  Debt Service                                   90933012
# 2017  Social Services                                78580101
# 2016  Social Services                                73270883
# 2015  Social Services                                70023056
# 2014  Social Services                                69153442
# 2013  Social Services                                67834829
# 2018  Law Enforcement                                66601596
# 2017  Law Enforcement                                65125442
# 2018  Social Services                                64922230
# 2016  Law Enforcement                                64878973
# 2015  Law Enforcement                                63925042
# 2013  Law Enforcement                                63067577
# 2014  Law Enforcement                                62514387
# 2018  Health Care & Wellness                         42493002
# 2014  Health Care & Wellness                         40756263
# 2017  Health Care & Wellness                         40008808
# 2016  Health Care & Wellness                         39114318
# 2015  Health Care & Wellness                         38263174
# 2013  Health Care & Wellness                         37464478
#                                                       ...
#       County Commissioners                             436259
# 2014  County Commissioners                             406196
# 2017  Purchasing                                       400959
# 2016  Purchasing                                       399036
# 2018  Purchasing                                       394462
# 2015  Purchasing                                       388429
# 2018  Family Justice Center                            380126
# 2014  Purchasing                                       351774
# 2013  Purchasing                                       343223
# 2018  Southeast Fire Prot Dist                         329508
#       Clerk to the Board                               305477
# 2017  Soil & Water Conservation                        285461
#       Family Justice Center                            277312
# 2013  Clerk to the Board                               260868
# 2016  Soil & Water Conservation                        259959
# 2015  Soil & Water Conservation                        257494
# 2013  Soil & Water Conservation                        245859
# 2014  Soil & Water Conservation                        245165
# 2013  Property Management                              236386
# 2016  Family Justice Center                            231551
# 2017  Clerk to the Board                               207020
# 2016  Clerk to the Board                               205886
# 2014  Clerk to the Board                               197273
# 2013  Capital Outlay                                   174914
# 2014  Property Management                              173117
# 2015  Clerk to the Board                               169882
# 2016  Veteran Services                                 127273
# 2015  Veteran Services                                 124772
# 2013  Veteran Services                                 122177
# 2014  Veteran Services                                 121372
# Name: Amount, Length: 269, dtype: int64

# %%
least=Expense_Budget[Expense_Budget["Dept Name"]=="Veteran Services"].groupby(by=["Year","Dept Name"])["Amount"].mean().sort_values(ascending = False)

# %%
maxm=Expense_Budget[Expense_Budget["Dept Name"]=="Guilford County Public Schools - Operating"].groupby(by=["Year","Dept Name"])["Amount"].mean().sort_values(ascending = False)

# %%
sns.distplot(least.values, hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 5},
             hist_kws={"linewidth": 15,'alpha':1},
             label = 'a')
sns.distplot(maxm.values, hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 5},
             hist_kws={"linewidth": 15,'alpha':1},
             label="b"
             )
# sns.set(xlabel='Amount', ylabel='Probability')
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
ax = sns.distplot(maxm.values,
                  kde=True,
                  hist=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Amount', ylabel='Probability')
# Out:
# [Text(0,0.5,'Probability'), Text(0.5,0,'Amount')]

# %%
least.values
# Out:
# array([127273, 124772, 122177, 121372], dtype=int64)

# %%
sns.distplot(a.groupby("Year").Amount.mean(), hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 3},
             hist_kws={"linewidth": 15,'alpha':1},
             label = 'Emergency Services')
sns.distplot(b.groupby("Year").Amount.mean(), hist = False,
             kde = True,
             kde_kws = {'shade': True, 'linewidth': 3},
             hist_kws={"linewidth": 15,'alpha':1},
             label="Health Care & Wellness"
             )
# plt.set_label(xlabel='Amount', ylabel='Probability')
plt.xlabel("Amount")
plt.ylabel("Probability")
# plt.xlim(1.0)
plt.show()

# %%
ax = sns.distplot(Expense_Budget.Amount,
                  kde=True,
                  hist=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Amount', ylabel='Probability')
# Out:
# [Text(0,0.5,'Probability'), Text(0.5,0,'Amount')]
