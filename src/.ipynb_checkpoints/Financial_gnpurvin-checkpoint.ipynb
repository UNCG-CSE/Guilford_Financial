# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/budgets.csv')

# %%
data.head()
# Out:
#    Service #                   Service Name  Fund #     Fund Fund- # & Name  \
# 0   250115.0        Medicaid Transportation   100.0  General    100-General
# 1   175310.0          Distribution Services   100.0  General    100-General
# 2   310730.0       DS-Prison Farm Operation   100.0  General    100-General
# 3   210130.0                    Child Abuse   100.0  General    100-General
# 4   210270.0  Tobacco Prevention-Youth Proj   100.0  General    100-General
#
#    Dept #                        Dept Name  SubDept#  \
# 0   250.0  Transportation - Human Services      10.0
# 1   175.0                       Facilities      30.0
# 2   310.0                  Law Enforcement      40.0
# 3   210.0                    Public Health      10.0
# 4   210.0                    Public Health      10.0
#
#                 SubDept Name      Service Area     Type   Acct #  \
# 0  Transportation-Human Serv    Human Services  Expense  58900.0
# ...
