# %% [markdown]
# Markdown:
# In the First line we importing random library.
# In the Second line we are using list comprehension is used to generate list of strings which contains the students name and roll_id and assigning it to lst
# In the third line we are shuffling the list
# In the fourth line list comprehension is used to generate a list of list based on number of team members we want in our teams.

# %%
import pandas as pd

# %%
df_budget=pd.read_excel("../data/2013-2018 Adopted Budgets.xlsx")

# %%
df_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27155 entries, 0 to 27154
# Data columns (total 20 columns):
# Service #         27155 non-null int64
# Service Name      27155 non-null object
# Fund #            27155 non-null int64
# Fund              27155 non-null object
# Fund- # & Name    27155 non-null object
# Dept #            27155 non-null int64
# Dept Name         27155 non-null object
# SubDept#          27155 non-null int64
# SubDept Name      27155 non-null object
# Service Area      27155 non-null object
# Type              27155 non-null object
# Acct #            27155 non-null int64
# Acct Name         27155 non-null object
# ExpSort           22164 non-null float64
# Acct Cat          27155 non-null object
# AU All            27155 non-null object
# budgetType        27155 non-null object
# Amount            21924 non-null float64
# Year              27155 non-null int64
# PerCapita         27155 non-null float64
# dtypes: float64(3), int64(6), object(11)
# ...

# %%
df_budget.head()
# Out:
#    Service #                   Service Name  Fund #     Fund Fund- # & Name  \
# 0     250115        Medicaid Transportation     100  General    100-General
# 1     175310          Distribution Services     100  General    100-General
# 2     310730       DS-Prison Farm Operation     100  General    100-General
# 3     210130                    Child Abuse     100  General    100-General
# 4     210270  Tobacco Prevention-Youth Proj     100  General    100-General
#
#    Dept #                        Dept Name  SubDept#  \
# 0     250  Transportation - Human Services        10
# 1     175                       Facilities        30
# 2     310                  Law Enforcement        40
# 3     210                    Public Health        10
# 4     210                    Public Health        10
#
#                 SubDept Name      Service Area     Type  Acct #  \
# 0  Transportation-Human Serv    Human Services  Expense   58900
# ...

# %%
import matplotlib.pyplot as plt
df_budget["Type"].value_counts().plot(kind='bar')

# %%
df_budget_Expence=df_budget[df_budget.Type=="Expense"]

# %%
# df_budget_Expence=df_budget_Expence.groupby("Year")

# %%
# df_budget_Expence.groupby("Year")["Amount"].sum().plot(kind='bar')

# %%
df_budget_Expence.Amount.max()
# Out:
# 195860398.0

# %%
df_budget_Revenue=df_budget[df_budget.Type=="Revenue"]

# %%
df_budget_Revenue.Amount.max()
# Out:
# -1.0

# %%
df_budget.groupby(by=["Dept Name","SubDept Name"]).describe()
# Out:
#                                                                                         Acct #  \
#                                                                                          count
# Dept Name                               SubDept Name
# Alamance Fire Prot Dist                 Alamance Fire Prot Dist                           46.0
# Animal Services                         Animal Control                                   230.0
#                                         Animal Shelter                                   250.0
# Budget and Management                   Budget and Management                            117.0
# Capital Outlay                          Guilford County Capital Outlay                     7.0
# Child Support Enforcement               Child Support Enforcement                        212.0
# Clerk to the Board                      Clerk to the Board                               115.0
# ...

# %%
#df_budget.groupby(by=["Year","Amount"]).describe()

# %%
df_budget["Amount"].min()
# Out:
# -332140750.0

# %%
df_budget[df_budget["Type"]==""]
# Out:
# Empty DataFrame
# Columns: [Service #, Service Name, Fund #, Fund, Fund- # & Name, Dept #, Dept Name, SubDept#, SubDept Name, Service Area, Type, Acct #, Acct Name, ExpSort, Acct Cat, AU All, budgetType, Amount, Year, PerCapita]
# Index: []

# %%
df_budget.columns
# Out:
# Index([u'Service #', u'Service Name', u'Fund #', u'Fund', u'Fund- # & Name',
#        u'Dept #', u'Dept Name', u'SubDept#', u'SubDept Name', u'Service Area',
#        u'Type', u'Acct #', u'Acct Name', u'ExpSort', u'Acct Cat', u'AU All',
#        u'budgetType', u'Amount', u'Year', u'PerCapita'],
#       dtype='object')

# %%
df1=df_budget[df_budget["Year"]==2014]

# %%
df1.head()
# Out:
#       Service #                    Service Name  Fund #     Fund  \
# 5220     250115         Medicaid Transportation     100  General
# 5221     175310           Distribution Services     100  General
# 5222     310730        DS-Prison Farm Operation     100  General
# 5223     210130                     Child Abuse     100  General
# 5224     210002  Human Resrcs-Fiscal-Technology     100  General
#
#      Fund- # & Name  Dept #                        Dept Name  SubDept#  \
# 5220    100-General     250  Transportation - Human Services        10
# 5221    100-General     175                       Facilities        30
# 5222    100-General     310                  Law Enforcement        40
# 5223    100-General     210                    Public Health        10
# 5224    100-General     210                    Public Health         2
#
#                    SubDept Name      Service Area     Type  Acct #  \
# 5220  Transportation-Human Serv    Human Services  Expense   58900
# ...

# %%
df1.shape
# Out:
# (4642, 20)

# %%
df1.groupby("AU All").describe()
# Out:
#              Acct #                                                            \
#               count     mean std      min      25%      50%      75%      max
# AU All
# 100001-41101    1.0  41101.0 NaN  41101.0  41101.0  41101.0  41101.0  41101.0
# 100001-41102    1.0  41102.0 NaN  41102.0  41102.0  41102.0  41102.0  41102.0
# 100001-41103    1.0  41103.0 NaN  41103.0  41103.0  41103.0  41103.0  41103.0
# 100001-41104    1.0  41104.0 NaN  41104.0  41104.0  41104.0  41104.0  41104.0
# 100001-41113    1.0  41113.0 NaN  41113.0  41113.0  41113.0  41113.0  41113.0
# 100001-41201    1.0  41201.0 NaN  41201.0  41201.0  41201.0  41201.0  41201.0
# 100001-41202    1.0  41202.0 NaN  41202.0  41202.0  41202.0  41202.0  41202.0
# 100001-41203    1.0  41203.0 NaN  41203.0  41203.0  41203.0  41203.0  41203.0
# 100001-41212    1.0  41212.0 NaN  41212.0  41212.0  41212.0  41212.0  41212.0
# 100001-41213    1.0  41213.0 NaN  41213.0  41213.0  41213.0  41213.0  41213.0
# ...

# %%
#df1.groupby("Acct #").describe()

# %%
df2=df1[df1["Type"]=="Expense"]

# %%
#df2

# %%
df2["Amount"].max()
# Out:
# 177130398.0

# %%
df_trans=pd.read_csv("../data/Trans2.csv")

# %%
df_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886825 entries, 0 to 886824
# Data columns (total 5 columns):
# Entity         886825 non-null object
# Account        886825 non-null int64
# Date           886825 non-null object
# Description    878195 non-null object
# Amount         886825 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 33.8+ MB

# %%
df_trans.head()
# Out:
#        Entity  Account        Date                Description      Amount
# 0  100-100001    41101  07/01/2012   Record PY prpd txs as CY  -116018.63
# 1  100-100001    41103  07/01/2012   Record PY prpd txs as CY -1343129.12
# 2  100-100001    41201  07/01/2012  accrue sales&use tax 7/16  1901125.37
# 3  100-100001    41202  07/01/2012  accrue sales&use tax 7/16   866051.86
# 4  100-100001    41203  07/01/2012  accrue sales&use tax 7/16   575521.51

# %%
# df1=df_trans[df_trans["AU All"]=="250115-58900"]

# %%
# df1

# %%
#df["Fund #"].value_counts()

# %%
df_budget_Expence.columns
# Out:
# Index([u'Service #', u'Service Name', u'Fund #', u'Fund', u'Fund- # & Name',
#        u'Dept #', u'Dept Name', u'SubDept#', u'SubDept Name', u'Service Area',
#        u'Type', u'Acct #', u'Acct Name', u'ExpSort', u'Acct Cat', u'AU All',
#        u'budgetType', u'Amount', u'Year', u'PerCapita'],
#       dtype='object')

# %%
df_2013=df_budget_Expence[df_budget_Expence.Year==2013]

# %%
df_2013_positive=df_2013[df_2013.Amount > 0]

# %%
df_2013_negative=df_2013[df_2013.Amount < 0]

# %%
df_2013_negative.Amount.sum()
# Out:
# -3489595.0

# %%
df_2013_positive.Amount.sum()
# Out:
# 649473223.0

# %%
df_2013_negative.Amount.sum() + df_2013_positive.Amount.sum()
# Out:
# 645983628.0

# %%
import matplotlib.pyplot as plt
plt.ylabel("Amount")
# plt.figure(figsize=(15,10))
#plt.figsize(30,60)
plt.show(df_2013.groupby("Dept Name")["Amount"].sum().sort_values(ascending=False).plot(kind='bar',figsize=(15,5)))
# plt.show()

# %%
import matplotlib.pyplot as plt
plt.ylabel("Amount")
plt.figure(figsize=(15,10))
#plt.figsize(30,60)
plt.show(df_2013.groupby("Dept Name")["Amount"].sum().sort_values(ascending=False)[0:10].plot(kind='bar'))
# plt.show()

# df_2013.groupby("Dept Name")["Amount"].sum().plot

# %%
type(df_2013.groupby("Dept Name")["Amount"].sum())
# Out:
# pandas.core.series.Series

# %%
df_trans.head()
# Out:
#        Entity  Account        Date                Description      Amount
# 0  100-100001    41101  07/01/2012   Record PY prpd txs as CY  -116018.63
# 1  100-100001    41103  07/01/2012   Record PY prpd txs as CY -1343129.12
# 2  100-100001    41201  07/01/2012  accrue sales&use tax 7/16  1901125.37
# 3  100-100001    41202  07/01/2012  accrue sales&use tax 7/16   866051.86
# 4  100-100001    41203  07/01/2012  accrue sales&use tax 7/16   575521.51

# %%
# df_trans["Date"]=pd.to_datetime(df_trans["Date"])

# %%
df_trans.shape
# Out:
# (886825, 5)

# %%
df_trans.index
# Out:
# RangeIndex(start=0, stop=886825, step=1)

# %%
# df_trans=df_trans[0:301706]

# %%
df_trans["Date"]=pd.to_datetime(df_trans["Date"])

# %%
df_trans["month"]=df_trans["Date"].dt.month

# %%
df_trans["year"]=df_trans["Date"].dt.year

# %%
df_trans_GCS=df_trans[df_trans["Entity"]=="100-710010"]
df_trans_GCS_Expense=df_trans_GCS[df_trans_GCS["Account"]>=50000]

# %%
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2012].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2012")
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2013].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2013")
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2014].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2014")
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2015].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2015")
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2016].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2016")
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2017].groupby(by=["year","month"])["Amount"].sum().plot(kind="density",figsize=(8,8),label="2017")

# %%
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2012].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2013].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2014].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2015].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2016].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2017].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-c96925627817> in <module>()
# ----> 1 df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2012].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
#       2 df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2013].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
#       3 df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2014].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
#       4 df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2015].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
#       5 df_trans_GCS_Expense[df_trans_GCS_Expense["year"]==2016].groupby(by=["year","month"])["Amount"].plot(kind="density",figsize=(10,10))
#
# ...

# %%
df_trans_2012=df_trans[df_trans["year"]==2012]

# %%
df_trans_2013=df_trans[df_trans["year"]==2013]

# %%
df_trans_2013.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")

# %%
df_trans_2013.columns
# Out:
# Index(['Entity', 'Account', 'Date', 'Description', 'Amount', 'month', 'year'], dtype='object')

# %%
df_trans_2012_en=df_trans_2012[df_trans_2012["Entity"]=="100-710010"]
# df_trans_2012_en.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")
df_trans_2012_en_expense=df_trans_2012_en[df_trans_2012_en["Account"]>=50000]
df_trans_2012_en_expense.groupby(by=["month"])["Amount"].sum().plot(kind="density")
df_trans_2013_en_expense.groupby(by=["month"])["Amount"].sum().plot(kind="density")
# df_trans_2012_en.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")

# %%
df_trans_2013_en=df_trans_2013[df_trans_2013["Entity"]=="100-710010"]

# %%
df_trans_2013_en.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")

# %%
df_trans_2013_en_expense=df_trans_2013_en[df_trans_2013_en["Account"]>=50000]

# %%
df_trans_2013_en_expense.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")

# %%
df_trans_2013_en_expense.groupby(by=["month"])["Amount"].sum().plot(kind="density")

# %%
df_trans_2013_debit=df_trans_2013[df_trans_2013["Entity"]=="100-910110"]
df_trans_2013_debit_expense=df_trans_2013_debit[df_trans_2013_debit["Account"]>=50000]

# %%
df_trans_2013_debit_expense.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")

# %%
df_trans_2013_debit=df_trans_2013[df_trans_2013["Entity"]=="100-910110"]
df_trans_2013_debit_revenue=df_trans_2013_debit[df_trans_2013_debit["Account"]<50000]
df_trans_2013_debit_revenue.Amount=df_trans_2013_debit_revenue.Amount*-1
df_trans_2013_debit_revenue.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")
# Out:
# C:\Users\hp-pc\Anaconda3\lib\site-packages\pandas\core\generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_trans_2013_fund_level=df_trans_2013[df_trans_2013["Entity"]=="100-100001"]
df_trans_2013_fund_level_revenue=df_trans_2013_fund_level[df_trans_2013_fund_level["Account"]<50000]
df_trans_2013_fund_level_revenue.Amount=df_trans_2013_fund_level_revenue.Amount*-1
df_trans_2013_fund_level_revenue.groupby(by=["year","month"])["Amount"].sum().plot(kind="bar")
