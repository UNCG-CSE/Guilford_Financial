# %% [markdown]
# This finds all of the account numbers that get used, but don't have an account name mapped to it. Notably, each "rougue" account seems to either only get used once, or only gets used a few times.

# %%
import pandas as pd
import csv
import warnings
warnings.filterwarnings('ignore') # Disable warnings for now

# %%
df_budget = pd.read_csv("../data/Expense_Budget.csv")

# %%
# Map of account # to account name
acct_map = dict((int(row[0]), row[1]) for row in csv.reader(open("../data/account_map.csv", "r")))

# Map of service # to service name
srvc_map = dict((int(row[0]), row[1]) for row in csv.reader(open("../data/service_map.csv", "r")))

# %%
df_trans = pd.read_csv("../data/Trans2.csv")

# Convert the dates from strings to datetimes
# TODO: Figure out how to do this faster and without Python crying
df_trans["Date"] = pd.to_datetime(df_trans["Date"])

# %%
year = 2013

while year < 2018:
    print("[%d]" % year)

    # Operate only on the budget for the given year and the related subset of transactions
    df_budget_year = df_budget[df_budget.Year == year]    
    df_trans_year = df_trans[df_trans["Date"].dt.year == year]
    
    for dept_name in sorted(df_budget_year["Dept Name"].unique()):
        df_budget_dept = df_budget_year[df_budget_year["Dept Name"] == dept_name]
        fund_num = df_budget_dept["Fund #"].unique()[0]

        for service_num in sorted(df_budget_dept["Service #"].unique()):
            entity = str(fund_num) + "-" + str(service_num)

            # Get all of the transactions under the generated entity
            df_trans_entity = df_trans_year[df_trans_year["Entity"] == entity]
            
            missing_acct_nums = []
            
            for acct_num in sorted(df_trans_entity["Account"].unique()):
                df_trans_acct = df_trans_entity[df_trans_entity["Account"] == acct_num]

                if acct_num not in acct_map:
                    missing_acct_nums.append(acct_num)

            if missing_acct_nums:
                # dept_names get printed multiple times, but fixing it's
                # more trouble than it's worth
                print("\t%s" % dept_name)
                print("\t\t%s [%s]" % (srvc_map[service_num], entity))

                for acct_num in missing_acct_nums:
                    df_trans_acct = df_trans_entity[df_trans_entity["Account"] == acct_num]
                    print("\t\t\tUnknown Account [%s] - %f (%f)" % (acct_num, df_trans_acct["Amount"].sum(), df_trans_acct["Amount"].mean()))

    year += 1
# Out:
# [2013]
# 	Emergency Services
# 		Medical-Emergency Med Services [100-320410]
# 			Unknown Account [55360] - 258000.000000 (64500.000000)
# 	Fleet Operation
# 		Fleet Operation [100-191110]
# 			Unknown Account [55360] - 8375.000000 (8375.000000)
# 	Health Care & Wellness
# 		Medical - Choice Plus [200-197135]
# 			Unknown Account [49440] - -299166.570000 (-299166.570000)
# 	Law Enforcement
# 		SO-S Emer Response Team-FF DOJ [100-310234]
# 			Unknown Account [55010] - 311096.070000 (103698.690000)
# 			Unknown Account [55100] - 1807.170000 (1807.170000)
# 	Mental Health
# 		Area Administration [100-220002]
# 			Unknown Account [45310] - 0.000000 (0.000000)
# 	Mental Health
# 		AMH - Inpatient [100-220225]
# 			Unknown Account [44628] - -201750.000000 (-201750.000000)
# 	Public Health
# 		Human Resrcs-Fiscal-Technology [100-210002]
# 			Unknown Account [45310] - 0.000000 (0.000000)
# 			Unknown Account [55360] - 86811.200000 (43405.600000)
# 	Soil & Water Conservation
# 		Soil & Water Conservation [100-420110]
# 			Unknown Account [44112] - -13750.000000 (-13750.000000)
# 	Solid Waste
# 		Waste Disposal Administration [100-410002]
# 			Unknown Account [45206] - -1546.970000 (-1546.970000)
# 	Southeast Fire Prot Dist
# 		Soil & Water Conservation [100-420110]
# 			Unknown Account [44112] - -13750.000000 (-13750.000000)
# [2014]
# 	Child Support Enforcement
# 		Child Support Enforcement [100-240110]
# 			Unknown Account [55360] - 120060.000000 (120060.000000)
# 	Economic Development & Assistance
# 		Economic Develop & Assistance [100-650110]
# 			Unknown Account [44608] - -429513.000000 (-143171.000000)
# 	Health Care & Wellness
# 		Medical - Choice Plus [200-197135]
# 			Unknown Account [49440] - -355169.220000 (-355169.220000)
# 	Information Services
# 		IS Client Services [100-140210]
# 			Unknown Account [55360] - 92000.000000 (92000.000000)
# 	Public Health
# 		Human Resrcs-Fiscal-Technology [100-210002]
# 			Unknown Account [45310] - 0.000000 (0.000000)
# 			Unknown Account [55360] - 39357.000000 (39357.000000)
# 	Public Health
# 		Maternity Clinic-MedMax [100-210410]
# 			Unknown Account [55360] - 5411.000000 (5411.000000)
# 	Social Services
# 		Subsidized Day Care - Children [100-230220]
# 			Unknown Account [54110] - 3345.350000 (3345.350000)
# 	Solid Waste
# 		Other Disposal [100-410140]
# 			Unknown Account [45232] - 0.000000 (0.000000)
# [2015]
# 	Debt Service
# 		Debt Service [100-910110]
# 			Unknown Account [48152] - -233685.980000 (-233685.980000)
# 	Economic Development & Assistance
# 		Economic Develop & Assistance [100-650110]
# 			Unknown Account [44608] - -477360.000000 (-238680.000000)
# 	Health Care & Wellness
# 		Medical - Choice Plus [200-197135]
# 			Unknown Account [49440] - -381524.670000 (-381524.670000)
# 	Information Services
# 		IS Client Services [100-140210]
# 			Unknown Account [55360] - 85848.670000 (14308.111667)
# 	Law Enforcement
# 		SO-S Emer Response Team-FF DOJ [100-310234]
# 			Unknown Account [48150] - -55029.050000 (-55029.050000)
# 	Planning and Development
# 		P&D - Planning/Zoning [100-160110]
# 			Unknown Account [45931] - -3240.500000 (-360.055556)
# 	Public Health
# 		Human Resrcs-Fiscal-Technology [100-210002]
# 			Unknown Account [45310] - -0.000000 (-0.000000)
# 	Public Health
# 		Hazardous Response [100-210515]
# 			Unknown Account [45225] - -5500.000000 (-5500.000000)
# 			Unknown Account [45226] - -5500.000000 (-5500.000000)
# 	Public Health
# 		On-site Sewage/Water Supplies [100-210545]
# 			Unknown Account [45154] - -100.000000 (-100.000000)
# [2016]
# 	Debt Service
# 		Debt Service [100-910110]
# 			Unknown Account [46121] - -92930000.000000 (-92930000.000000)
# 			Unknown Account [46151] - -18891592.100000 (-18891592.100000)
# 			Unknown Account [56900] - 111191211.900000 (111191211.900000)
# 	Law Enforcement
# 		Special Operations Command [100-310200]
# 			Unknown Account [49508] - -3200.000000 (-3200.000000)
# 	Planning and Development
# 		P&D - Planning/Zoning [100-160110]
# 			Unknown Account [45931] - 3240.500000 (324.050000)
# 	Public Health
# 		Human Resrcs-Fiscal-Technology [100-210002]
# 			Unknown Account [45310] - -0.000000 (-0.000000)
# 			Unknown Account [49437] - -125000.000000 (-125000.000000)
# 	Social Services
# 		Agency General Administration [100-230002]
# 			Unknown Account [55360] - 71500.000000 (10214.285714)
# [2017]
# 	County Administration
# 		County Administration [100-105002]
# 			Unknown Account [53930] - 41.750000 (41.750000)
# 	Debt Service
# 		Debt Service [100-910110]
# 			Unknown Account [46101] - -24350000.000000 (-24350000.000000)
# 			Unknown Account [46141] - -23114593.700000 (-11557296.850000)
# 			Unknown Account [56900] - 24350000.000000 (24350000.000000)
# 	Economic Development & Assistance
# 		Economic Develop & Assistance [100-650110]
# 			Unknown Account [44608] - -180532.000000 (-180532.000000)
# 	Public Health
# 		Human Resrcs-Fiscal-Technology [100-210002]
# 			Unknown Account [45310] - 0.000000 (0.000000)
# 			Unknown Account [53930] - 2389.810000 (1194.905000)
