# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib

# %%
data = pd.read_csv('../data/Expense_Budget.csv')

# %%
data.head()
# Out:
#    Service #                   Service Name  Fund #     Fund Fund- # & Name  \
# 0     250115        Medicaid Transportation     100  General    100-General
# 1     175310          Distribution Services     100  General    100-General
# 2     310730       DS-Prison Farm Operation     100  General    100-General
# 3     210130                    Child Abuse     100  General    100-General
# 4     210270  Tobacco Prevention-Youth Proj     100  General    100-General
#
#    Dept #                        Dept Name  SubDept#  \
# 0     250  Transportation - Human Services        10
# 1     175                       Facilities        30
# 2     310                  Law Enforcement        40
# 3     210                    Public Health        10
# 4     210                    Public Health        10
#
#                 SubDept Name      Service Area     Type  Acct #  \
# 0  Transportation-Human Serv    Human Services  Expense   58900
# ...

# %%
data['Dept Name'].value_counts()
# Out:
# Public Health                                       6776
# Law Enforcement                                     3415
# Social Services                                     1728
# Recreation - Parks                                  1658
# Emergency Services                                  1241
# Facilities                                          1017
# Solid Waste                                          630
# Animal Services                                      423
# Information Services                                 410
# Planning and Development                             329
# Register of Deeds                                    310
# Transportation - Human Services                      239
# Purchasing                                           223
# Court Alternatives                                   220
# Elections                                            201
# Human Resources                                      184
# ...

# %%
x = list(data['Dept Name'].unique())

# %%
y1 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2013]
y2 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2014]
y3 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2015]
y4 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2016]
y5 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2017]
y6 = data.groupby(['Year','Dept Name'])['Amount'].mean().loc[2018]
df = pd.DataFrame({'2013': y1, '2014': y2, '2015': y3, '2016': y4, '2017': y5, '2018': y6})

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Department Name')
plt.ylabel('Expense')
plt.title('Expenses for Different Department')
plt.plot(x, y1,'r', data=data,label='2013')
plt.plot(x, y2,'g', data=data,label='2014')
plt.plot(x, y3,'y', data=data,label='2015')
plt.plot(x, y4,'orange', data=data,label='2016')
plt.plot(x, y5,'b', data=data,label='2017')
plt.plot(x, y6,'purple', data=data,label='2018')
plt.xticks(rotation=90)
plt.legend()
# plt.savefig("trends.png")

# %%
y1.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2013')
y2.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2014')
y3.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2015')
y4.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2016')
y5.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2017')
y6.plot(kind="density", figsize=(10,10), xlim=(-1.0* 10**8, 3* 10**8), label='2018')
plt.legend()
plt.xlabel('Expense')
plt.ylabel('Density')
plt.title('Density Graph of Total Expenses for Different Years')
plt.savefig("peak")

# %%
import seaborn as sns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21929 entries, 0 to 21928
# Data columns (total 19 columns):
# Service #         21929 non-null int64
# Service Name      21929 non-null object
# Fund #            21929 non-null int64
# Fund              21929 non-null object
# Fund- # & Name    21929 non-null object
# Dept #            21929 non-null int64
# Dept Name         21929 non-null object
# SubDept#          21929 non-null int64
# SubDept Name      21929 non-null object
# Service Area      21929 non-null object
# Type              21929 non-null object
# Acct #            21929 non-null int64
# Acct Name         21929 non-null object
# Acct Cat          21929 non-null object
# AU All            21929 non-null object
# budgetType        21929 non-null object
# Amount            21929 non-null int64
# Year              21929 non-null int64
# PerCapita         21929 non-null float64
# dtypes: float64(1), int64(7), object(11)
# memory usage: 3.2+ MB

# %%
data.describe()
# Out:
#            Service #        Fund #        Dept #      SubDept#        Acct #  \
# count   21929.000000  21929.000000  21929.000000  21929.000000  21929.000000
# mean   263814.132655    101.167404    263.541338     22.898627  52107.276255
# std    107035.354441     10.741640    107.008826     19.481888   1054.666000
# min    101110.000000    100.000000    101.000000      2.000000  51010.000000
# 25%    210170.000000    100.000000    210.000000     10.000000  51210.000000
# 50%    210720.000000    100.000000    210.000000     20.000000  52010.000000
# 75%    310701.000000    100.000000    310.000000     30.000000  53060.000000
# max    910110.000000    200.000000    910.000000     90.000000  58900.000000
#
#              Amount          Year     PerCapita
# count  2.192900e+04  21929.000000  21929.000000
# mean   1.717189e+05   2015.355237      0.334004
# std    3.285759e+06      1.706303      6.386587
# min   -2.725474e+06   2013.000000     -5.431265
# ...

# %%
# sns.pairplot(df)

# %%
sns.distplot(df['2013'])
# Out:
# /anaconda2/lib/python2.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.describe()
# Out:
#                2013          2014          2015          2016          2017  \
# count  4.800000e+01  4.800000e+01  4.800000e+01  4.800000e+01  4.800000e+01
# mean   4.344757e+06  4.462114e+06  4.669616e+06  4.839675e+06  4.903773e+06
# std    2.535809e+07  2.556902e+07  2.588256e+07  2.645920e+07  2.719024e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.151927e+04  2.097365e+04  2.541733e+04  3.017682e+04  2.632431e+04
# 50%    6.193783e+04  5.520555e+04  5.633946e+04  8.084584e+04  7.127569e+04
# 75%    1.621056e+05  1.899810e+05  2.036744e+05  2.839809e+05  2.416886e+05
# max    1.756304e+08  1.771304e+08  1.793604e+08  1.833604e+08  1.883604e+08
#
#                2018
# count  4.800000e+01
# mean   5.201383e+06
# std    2.829755e+07
# min    0.000000e+00
# 25%    2.764804e+04
# 50%    8.265645e+04
# 75%    2.760894e+05
# max    1.958604e+08

# %%
df.head()
# Out:
#                                     2013           2014           2015  \
# Dept Name
# Animal Services             44517.309859   44815.449275   45209.492754
# Budget and Management       22748.400000   23699.842105   24968.789474
# Capital Outlay              87457.000000       0.000000       0.000000
# Child Support Enforcement  182821.424242  204854.451613  193364.612903
# Clerk to the Board          12422.285714   10382.789474    8941.157895
#
#                                    2016           2017          2018
# Dept Name
# Animal Services            4.801680e+04   44237.464286  6.000489e+04
# Budget and Management      2.622733e+04   25248.315789  2.695800e+04
# Capital Outlay             1.800000e+06  750000.000000  2.000000e+06
# Child Support Enforcement  2.147437e+05  202422.451613  2.336893e+05
# Clerk to the Board         1.143811e+04   10351.000000  1.796924e+04

# %%
df_transposed = df.T
df_transposed
# Out:
# Dept Name  Animal Services  Budget and Management  Capital Outlay  \
# 2013          44517.309859           22748.400000         87457.0
# 2014          44815.449275           23699.842105             0.0
# 2015          45209.492754           24968.789474             0.0
# 2016          48016.803030           26227.333333       1800000.0
# 2017          44237.464286           25248.315789        750000.0
# 2018          60004.890625           26958.000000       2000000.0
#
# Dept Name  Child Support Enforcement  Clerk to the Board  \
# 2013                   182821.424242        12422.285714
# 2014                   204854.451613        10382.789474
# 2015                   193364.612903         8941.157895
# 2016                   214743.724138        11438.111111
# 2017                   202422.451613        10351.000000
# 2018                   233689.333333        17969.235294
#
# Dept Name  Cooperative Extension Service  Coordinated Services  \
# ...

# %%
# sns.pairplot(df_transposed)
df_transposed.index.name = "Year"

# %%
df_transposed
# Out:
# Dept Name  Animal Services  Budget and Management  Capital Outlay  \
# Year
# 2013          44517.309859           22748.400000         87457.0
# 2014          44815.449275           23699.842105             0.0
# 2015          45209.492754           24968.789474             0.0
# 2016          48016.803030           26227.333333       1800000.0
# 2017          44237.464286           25248.315789        750000.0
# 2018          60004.890625           26958.000000       2000000.0
#
# Dept Name  Child Support Enforcement  Clerk to the Board  \
# Year
# 2013                   182821.424242        12422.285714
# 2014                   204854.451613        10382.789474
# 2015                   193364.612903         8941.157895
# 2016                   214743.724138        11438.111111
# 2017                   202422.451613        10351.000000
# 2018                   233689.333333        17969.235294
#
# Dept Name  Cooperative Extension Service  Coordinated Services  \
# Year
# ...

# %%
df_transposed.columns
# Out:
# Index([u'Animal Services', u'Budget and Management', u'Capital Outlay',
#        u'Child Support Enforcement', u'Clerk to the Board',
#        u'Cooperative Extension Service', u'Coordinated Services',
#        u'County Administration', u'County Attorney', u'County Commissioners',
#        u'Court Alternatives', u'Culture & Libraries', u'Debt Service',
#        u'Economic Development & Assistance', u'Elections',
#        u'Emergency Services', u'Facilities', u'Family Justice Center',
#        u'Finance', u'Fleet Operation',
#        u'Guilford County Public Schools - Capital',
#        u'Guilford County Public Schools - Operating',
#        u'Guilford Technical Community College - Capital',
#        u'Guilford Technical Community College - Operating',
#        u'Health Care & Wellness', u'Human Resources', u'Information Services',
#        u'Inspections', u'Internal Audit', u'Law Enforcement', u'Mental Health',
#        u'Other Protection', u'Planning and Development',
# ...

# %%
df_transposed.index
# Out:
# Index([u'2013', u'2014', u'2015', u'2016', u'2017', u'2018'], dtype='object', name=u'Year')

# %%
# sns.pairplot(df_transposed)

# %%
sns.distplot(df_transposed['Public Health'], )

# %%
sns.heatmap(df_transposed.corr(), annot=True)
plt.savefig("heatmap")
